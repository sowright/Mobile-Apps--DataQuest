# %% [markdown]
# # Google and Apple Apps Data Analysis - Part 2
#
# Recall the goal for this project: to analyze datasets for [Google](https://www.kaggle.com/lava18/google-play-store-apps/version/6) and [Apple](https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps) apps and advise our client on which type of app would perform well in both markets.
#
# In the first notebook, we cleaned and transformed our data. In this second part we analyze calculate some metrics by app genre to make a recommendation on which genres tend to be most successful on both platforms.

# %% [markdown]
# ## I. Import and Review Transformed Data.

# %%
from csv import reader

open_file_google = open('google_data_transformed.csv', encoding="utf-8")
read_file_google = reader(open_file_google)
google_data = list(read_file_google)

open_file_apple = open('apple_data_transformed.csv', encoding="utf-8")
read_file_apple = reader(open_file_apple)
apple_data = list(read_file_apple)

# %%
# We use the same function we defined in the first notebook to explore the data

def explore_data(dataset, start, end, rows_and_columns=False, header=False):  
    
    if rows_and_columns:
        # print number of rows
        if header:
            print('Number of rows with data:', len(dataset)-1) # account for header row by subtracting one from total row count
        else:
            print('Number of rows:', len(dataset))
        
        # print number of columns
        print('Number of columns:', len(dataset[0]))
        print('\n')
    
    dataset_slice = dataset[start:end]
    for row in dataset_slice:
        print(row)
        print('\n') # adds a new (empty) line after each row

# %%
explore_data(google_data, 0, 3, rows_and_columns=True, header=True)
# Out:
# Number of rows with data: 8848
# Number of columns: 13
#
#
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']

# %%
explore_data(apple_data, 0, 3, rows_and_columns=True, header=True)
# Out:
# Number of rows with data: 4054
# Number of columns: 16
#
#
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']

# %% [markdown]
# ## II. Investigate Variables
#
# We look at what the most common genres are.
#
# The Google data has two fields that may give us this information - "Categories" and "Genres". We examine both.
#
# In the Apple data there is a field labelled "prime_genre" which seems to be exactly what we are looking for.

# %%
# Look at Google data field "Genres"

genres_google = []
for row in google_data[1:]:
    genre = row[9]
    if genre not in genres_google:
        genres_google.append(genre)

print(len(genres_google))
genres_google
# Out:
# 114
# ['Art & Design',
#  'Art & Design;Creativity',
#  'Auto & Vehicles',
#  'Beauty',
#  'Books & Reference',
#  'Business',
#  'Comics',
#  'Comics;Creativity',
#  'Communication',
#  'Dating',
#  'Education',
#  'Education;Creativity',
#  'Education;Education',
#  'Education;Pretend Play',
#  'Education;Brain Games',
#  'Entertainment',
#  'Entertainment;Brain Games',
#  'Entertainment;Creativity',
#  'Entertainment;Music & Video',
#  'Events',
#  'Finance',
#  'Food & Drink',
#  'Health & Fitness',
#  'House & Home',
#  'Libraries & Demo',
#  'Lifestyle',
#  'Lifestyle;Pretend Play',
#  'Card',
#  'Arcade',
#  'Puzzle',
#  'Racing',
#  'Sports',
#  'Casual',
#  'Simulation',
#  'Adventure',
#  'Trivia',
#  'Action',
#  'Word',
#  'Role Playing',
#  'Strategy',
#  'Board',
#  'Music',
#  'Action;Action & Adventure',
#  'Casual;Brain Games',
#  'Educational;Creativity',
#  'Puzzle;Brain Games',
#  'Educational;Education',
#  'Casual;Pretend Play',
#  'Educational;Brain Games',
#  'Art & Design;Pretend Play',
#  'Educational;Pretend Play',
#  'Entertainment;Education',
#  'Casual;Education',
#  'Casual;Creativity',
#  'Casual;Action & Adventure',
#  'Music;Music & Video',
#  'Arcade;Pretend Play',
#  'Adventure;Action & Adventure',
#  'Role Playing;Action & Adventure',
#  'Simulation;Pretend Play',
#  'Puzzle;Creativity',
#  'Simulation;Action & Adventure',
#  'Racing;Action & Adventure',
#  'Sports;Action & Adventure',
#  'Educational;Action & Adventure',
#  'Arcade;Action & Adventure',
#  'Entertainment;Action & Adventure',
#  'Art & Design;Action & Adventure',
#  'Puzzle;Action & Adventure',
#  'Education;Action & Adventure',
#  'Strategy;Action & Adventure',
#  'Music & Audio;Music & Video',
#  'Health & Fitness;Education',
#  'Board;Action & Adventure',
#  'Board;Brain Games',
#  'Casual;Music & Video',
#  'Education;Music & Video',
#  'Role Playing;Pretend Play',
#  'Entertainment;Pretend Play',
#  'Medical',
#  'Social',
#  'Shopping',
#  'Photography',
#  'Travel & Local',
#  'Travel & Local;Action & Adventure',
#  'Tools',
#  'Tools;Education',
#  'Personalization',
#  'Productivity',
#  'Parenting',
#  'Parenting;Music & Video',
#  'Parenting;Education',
#  'Parenting;Brain Games',
#  'Weather',
#  'Video Players & Editors',
#  'Video Players & Editors;Music & Video',
#  'Video Players & Editors;Creativity',
#  'News & Magazines',
#  'Maps & Navigation',
#  'Health & Fitness;Action & Adventure',
#  'Educational',
#  'Casino',
#  'Trivia;Education',
#  'Lifestyle;Education',
#  'Card;Action & Adventure',
#  'Books & Reference;Education',
#  'Simulation;Education',
#  'Puzzle;Education',
#  'Adventure;Education',
#  'Role Playing;Brain Games',
#  'Strategy;Education',
#  'Racing;Pretend Play',
#  'Communication;Creativity',
#  'Strategy;Creativity']

# %%
# Look at Google data field "Category"

categories_google = []
for row in google_data[1:]:
    category = row[1]
    if category not in categories_google:
        categories_google.append(category)

print(len(categories_google))
categories_google
# Out:
# 33
# ['ART_AND_DESIGN',
#  'AUTO_AND_VEHICLES',
#  'BEAUTY',
#  'BOOKS_AND_REFERENCE',
#  'BUSINESS',
#  'COMICS',
#  'COMMUNICATION',
#  'DATING',
#  'EDUCATION',
#  'ENTERTAINMENT',
#  'EVENTS',
#  'FINANCE',
#  'FOOD_AND_DRINK',
#  'HEALTH_AND_FITNESS',
#  'HOUSE_AND_HOME',
#  'LIBRARIES_AND_DEMO',
#  'LIFESTYLE',
#  'GAME',
#  'FAMILY',
#  'MEDICAL',
#  'SOCIAL',
#  'SHOPPING',
#  'PHOTOGRAPHY',
#  'SPORTS',
#  'TRAVEL_AND_LOCAL',
#  'TOOLS',
#  'PERSONALIZATION',
#  'PRODUCTIVITY',
#  'PARENTING',
#  'WEATHER',
#  'VIDEO_PLAYERS',
#  'NEWS_AND_MAGAZINES',
#  'MAPS_AND_NAVIGATION']

# %%
# Look at Apple data field "prime_genre"

genres_apple = []
for row in apple_data[1:]:
    genre = row[11]
    if genre not in genres_apple:
        genres_apple.append(genre)

print(len(genres_apple))
genres_apple
# Out:
# 23
# ['Social Networking',
#  'Photo & Video',
#  'Games',
#  'Music',
#  'Reference',
#  'Health & Fitness',
#  'Weather',
#  'Utilities',
#  'Travel',
#  'Shopping',
#  'News',
#  'Navigation',
#  'Lifestyle',
#  'Entertainment',
#  'Food & Drink',
#  'Sports',
#  'Book',
#  'Finance',
#  'Education',
#  'Productivity',
#  'Business',
#  'Catalogs',
#  'Medical']

# %% [markdown]
# In comparing the values in the fields "Category" and "Genres" of the Google dataset, we note that there is significant overlap. It seems that "Genre" breaks down some variables in Category into more precise classifications, and sometimes includes a secondary subgenre label in the string value.
#
# See examples below; the Category values "GAMES" and "FAMILY", for instance, have different values in the Genre field, whereas "BEAUTY"/"Beauty" is the same in both fields.

# %%
# Compare google_data fields "Category" and "Genres"

for row in google_data:
    print([row[1], row[9]])
# Out:
# ['Category', 'Genres']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design;Creativity']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design;Creativity']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design;Creativity']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design;Creativity']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['ART_AND_DESIGN', 'Art & Design']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BEAUTY', 'Beauty']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics;Creativity']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics']
# ['COMICS', 'Comics']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['DATING', 'Dating']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education;Creativity']
# ['EDUCATION', 'Education;Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education;Education']
# ['EDUCATION', 'Education;Creativity']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education;Pretend Play']
# ['EDUCATION', 'Education;Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education;Brain Games']
# ['EDUCATION', 'Education;Brain Games']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education;Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education;Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education']
# ['EDUCATION', 'Education;Education']
# ['EDUCATION', 'Education']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment;Brain Games']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment;Creativity']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment;Music & Video']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment;Music & Video']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment;Music & Video']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['ENTERTAINMENT', 'Entertainment']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['EVENTS', 'Events']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HOUSE_AND_HOME', 'House & Home']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle;Pretend Play']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['LIFESTYLE', 'Lifestyle']
# ['GAME', 'Card']
# ['GAME', 'Arcade']
# ['GAME', 'Arcade']
# ['GAME', 'Puzzle']
# ['GAME', 'Racing']
# ['GAME', 'Puzzle']
# ['GAME', 'Sports']
# ['GAME', 'Arcade']
# ['GAME', 'Casual']
# ['GAME', 'Puzzle']
# ['GAME', 'Simulation']
# ['GAME', 'Casual']
# ['GAME', 'Puzzle']
# ['GAME', 'Arcade']
# ['GAME', 'Adventure']
# ['GAME', 'Casual']
# ['GAME', 'Arcade']
# ['GAME', 'Arcade']
# ['GAME', 'Puzzle']
# ['GAME', 'Arcade']
# ['GAME', 'Arcade']
# ['GAME', 'Racing']
# ['GAME', 'Casual']
# ['GAME', 'Arcade']
# ['GAME', 'Arcade']
# ['GAME', 'Arcade']
# ['GAME', 'Arcade']
# ['GAME', 'Puzzle']
# ['GAME', 'Trivia']
# ['GAME', 'Simulation']
# ['GAME', 'Action']
# ['GAME', 'Arcade']
# ['GAME', 'Puzzle']
# ['GAME', 'Arcade']
# ['GAME', 'Arcade']
# ['GAME', 'Sports']
# ['GAME', 'Arcade']
# ['GAME', 'Action']
# ['GAME', 'Racing']
# ['GAME', 'Word']
# ['GAME', 'Action']
# ['GAME', 'Arcade']
# ['GAME', 'Adventure']
# ['GAME', 'Racing']
# ['GAME', 'Role Playing']
# ['GAME', 'Strategy']
# ['GAME', 'Board']
# ['GAME', 'Word']
# ['GAME', 'Sports']
# ['GAME', 'Action']
# ['GAME', 'Arcade']
# ['GAME', 'Casual']
# ['GAME', 'Simulation']
# ['GAME', 'Action']
# ['GAME', 'Action']
# ['GAME', 'Strategy']
# ['GAME', 'Simulation']
# ['GAME', 'Strategy']
# ['GAME', 'Role Playing']
# ['GAME', 'Strategy']
# ['GAME', 'Strategy']
# ['GAME', 'Role Playing']
# ['GAME', 'Strategy']
# ['GAME', 'Strategy']
# ['GAME', 'Role Playing']
# ['GAME', 'Action']
# ['GAME', 'Strategy']
# ['GAME', 'Casual']
# ['GAME', 'Action']
# ['GAME', 'Simulation']
# ['GAME', 'Casual']
# ['GAME', 'Simulation']
# ['GAME', 'Simulation']
# ['GAME', 'Card']
# ['GAME', 'Puzzle']
# ['GAME', 'Role Playing']
# ['GAME', 'Role Playing']
# ['GAME', 'Role Playing']
# ['GAME', 'Strategy']
# ['GAME', 'Role Playing']
# ['GAME', 'Role Playing']
# ['GAME', 'Role Playing']
# ['GAME', 'Role Playing']
# ['GAME', 'Strategy']
# ['GAME', 'Strategy']
# ['GAME', 'Casual']
# ['GAME', 'Sports']
# ['GAME', 'Arcade']
# ['GAME', 'Casual']
# ['GAME', 'Puzzle']
# ['GAME', 'Puzzle']
# ['GAME', 'Strategy']
# ['GAME', 'Strategy']
# ['GAME', 'Strategy']
# ['GAME', 'Puzzle']
# ['GAME', 'Arcade']
# ['GAME', 'Casual']
# ['GAME', 'Puzzle']
# ['GAME', 'Casual']
# ['GAME', 'Word']
# ['GAME', 'Casual']
# ['GAME', 'Action']
# ['GAME', 'Arcade']
# ['GAME', 'Casual']
# ['GAME', 'Casual']
# ['GAME', 'Puzzle']
# ['GAME', 'Arcade']
# ['GAME', 'Sports']
# ['GAME', 'Music']
# ['GAME', 'Puzzle']
# ['GAME', 'Arcade']
# ['GAME', 'Sports']
# ['GAME', 'Puzzle']
# ['GAME', 'Casual']
# ['GAME', 'Casual']
# ['GAME', 'Action']
# ['GAME', 'Casual']
# ['GAME', 'Arcade']
# ['GAME', 'Arcade']
# ['GAME', 'Arcade']
# ['GAME', 'Action']
# ['GAME', 'Action']
# ['GAME', 'Action']
# ['GAME', 'Action']
# ['GAME', 'Action']
# ['GAME', 'Action']
# ['GAME', 'Action']
# ['GAME', 'Action']
# ['GAME', 'Action']
# ['GAME', 'Action']
# ['GAME', 'Action']
# ['GAME', 'Action']
# ['GAME', 'Action']
# ['GAME', 'Action']
# ['GAME', 'Action']
# ['GAME', 'Action']
# ['GAME', 'Action']
# ['GAME', 'Action']
# ['GAME', 'Action']
# ['GAME', 'Action']
# ['GAME', 'Action']
# ['GAME', 'Action']
# ['GAME', 'Action;Action & Adventure']
# ['GAME', 'Action']
# ['GAME', 'Action']
# ['GAME', 'Action']
# ['GAME', 'Action']
# ['GAME', 'Action']
# ['GAME', 'Action']
# ['GAME', 'Action']
# ['GAME', 'Trivia']
# ['GAME', 'Arcade']
# ['GAME', 'Casual']
# ['GAME', 'Casual']
# ['GAME', 'Casual']
# ['GAME', 'Racing']
# ['GAME', 'Racing']
# ['GAME', 'Racing']
# ['GAME', 'Arcade']
# ['GAME', 'Casual;Brain Games']
# ['GAME', 'Action']
# ['GAME', 'Puzzle']
# ['GAME', 'Arcade']
# ['GAME', 'Puzzle']
# ['GAME', 'Puzzle']
# ['GAME', 'Arcade']
# ['GAME', 'Arcade']
# ['GAME', 'Arcade']
# ['GAME', 'Racing']
# ['GAME', 'Puzzle']
# ['GAME', 'Casual']
# ['GAME', 'Casual']
# ['GAME', 'Action']
# ['GAME', 'Board']
# ['GAME', 'Strategy']
# ['GAME', 'Action']
# ['GAME', 'Puzzle']
# ['GAME', 'Puzzle']
# ['GAME', 'Puzzle']
# ['GAME', 'Arcade']
# ['GAME', 'Arcade']
# ['GAME', 'Arcade']
# ['GAME', 'Action']
# ['GAME', 'Word']
# ['FAMILY', 'Casual;Brain Games']
# ['FAMILY', 'Educational;Creativity']
# ['FAMILY', 'Puzzle;Brain Games']
# ['FAMILY', 'Educational;Education']
# ['FAMILY', 'Casual;Brain Games']
# ['FAMILY', 'Educational;Education']
# ['FAMILY', 'Casual;Brain Games']
# ['FAMILY', 'Education;Creativity']
# ['FAMILY', 'Casual;Pretend Play']
# ['FAMILY', 'Casual;Brain Games']
# ['FAMILY', 'Casual;Brain Games']
# ['FAMILY', 'Education;Creativity']
# ['FAMILY', 'Educational;Education']
# ['FAMILY', 'Educational;Brain Games']
# ['FAMILY', 'Art & Design;Pretend Play']
# ['FAMILY', 'Educational;Pretend Play']
# ['FAMILY', 'Education;Education']
# ['FAMILY', 'Educational;Education']
# ['FAMILY', 'Entertainment;Education']
# ['FAMILY', 'Entertainment;Brain Games']
# ['FAMILY', 'Casual;Education']
# ['FAMILY', 'Educational;Education']
# ['FAMILY', 'Casual;Brain Games']
# ['FAMILY', 'Casual;Creativity']
# ['FAMILY', 'Casual;Brain Games']
# ['FAMILY', 'Casual;Pretend Play']
# ['FAMILY', 'Educational;Education']
# ['FAMILY', 'Casual;Creativity']
# ['FAMILY', 'Casual;Action & Adventure']
# ['FAMILY', 'Music;Music & Video']
# ['FAMILY', 'Educational;Education']
# ['FAMILY', 'Entertainment;Brain Games']
# ['FAMILY', 'Casual;Brain Games']
# ['FAMILY', 'Educational;Education']
# ['FAMILY', 'Music;Music & Video']
# ['FAMILY', 'Educational;Education']
# ['FAMILY', 'Education;Education']
# ['FAMILY', 'Educational;Education']
# ['FAMILY', 'Educational;Brain Games']
# ['FAMILY', 'Educational;Pretend Play']
# ['FAMILY', 'Arcade;Pretend Play']
# ['FAMILY', 'Educational;Education']
# ['FAMILY', 'Action;Action & Adventure']
# ['FAMILY', 'Casual;Action & Adventure']
# ['FAMILY', 'Education;Education']
# ['FAMILY', 'Puzzle;Brain Games']
# ['FAMILY', 'Education;Education']
# ['FAMILY', 'Casual;Action & Adventure']
# ['FAMILY', 'Education;Education']
# ['FAMILY', 'Education;Pretend Play']
# ['FAMILY', 'Adventure;Action & Adventure']
# ['FAMILY', 'Role Playing;Action & Adventure']
# ['FAMILY', 'Simulation;Pretend Play']
# ['FAMILY', 'Education;Education']
# ['FAMILY', 'Educational;Brain Games']
# ['FAMILY', 'Puzzle;Creativity']
# ['FAMILY', 'Simulation;Action & Adventure']
# ['FAMILY', 'Simulation;Action & Adventure']
# ['FAMILY', 'Racing;Action & Adventure']
# ['FAMILY', 'Sports;Action & Adventure']
# ['FAMILY', 'Simulation;Action & Adventure']
# ['FAMILY', 'Simulation;Action & Adventure']
# ['FAMILY', 'Casual;Action & Adventure']
# ['FAMILY', 'Racing;Action & Adventure']
# ['FAMILY', 'Racing;Action & Adventure']
# ['FAMILY', 'Educational;Action & Adventure']
# ['FAMILY', 'Simulation;Action & Adventure']
# ['FAMILY', 'Racing;Action & Adventure']
# ['FAMILY', 'Racing;Action & Adventure']
# ['FAMILY', 'Educational;Action & Adventure']
# ['FAMILY', 'Racing;Action & Adventure']
# ['FAMILY', 'Racing;Action & Adventure']
# ['FAMILY', 'Arcade;Action & Adventure']
# ['FAMILY', 'Entertainment;Action & Adventure']
# ['FAMILY', 'Casual;Action & Adventure']
# ['FAMILY', 'Casual;Action & Adventure']
# ['FAMILY', 'Art & Design;Action & Adventure']
# ['FAMILY', 'Puzzle;Action & Adventure']
# ['FAMILY', 'Education;Action & Adventure']
# ['FAMILY', 'Casual;Action & Adventure']
# ['FAMILY', 'Action;Action & Adventure']
# ['FAMILY', 'Education;Action & Adventure']
# ['FAMILY', 'Casual;Action & Adventure']
# ['FAMILY', 'Simulation;Action & Adventure']
# ['FAMILY', 'Racing;Action & Adventure']
# ['FAMILY', 'Adventure;Action & Adventure']
# ['FAMILY', 'Racing;Action & Adventure']
# ['FAMILY', 'Arcade;Action & Adventure']
# ['FAMILY', 'Racing;Action & Adventure']
# ['FAMILY', 'Educational;Pretend Play']
# ['FAMILY', 'Educational;Education']
# ['FAMILY', 'Casual;Pretend Play']
# ['FAMILY', 'Casual;Pretend Play']
# ['FAMILY', 'Educational;Brain Games']
# ['FAMILY', 'Puzzle;Brain Games']
# ['FAMILY', 'Casual;Pretend Play']
# ['FAMILY', 'Simulation;Action & Adventure']
# ['FAMILY', 'Strategy;Action & Adventure']
# ['FAMILY', 'Arcade;Action & Adventure']
# ['FAMILY', 'Entertainment;Music & Video']
# ['FAMILY', 'Music & Audio;Music & Video']
# ['FAMILY', 'Education;Education']
# ['FAMILY', 'Educational;Education']
# ['FAMILY', 'Health & Fitness;Education']
# ['FAMILY', 'Educational;Education']
# ['FAMILY', 'Educational;Education']
# ['FAMILY', 'Educational;Education']
# ['FAMILY', 'Puzzle;Brain Games']
# ['FAMILY', 'Board;Action & Adventure']
# ['FAMILY', 'Board;Brain Games']
# ['FAMILY', 'Board;Brain Games']
# ['FAMILY', 'Board;Brain Games']
# ['FAMILY', 'Puzzle;Brain Games']
# ['FAMILY', 'Puzzle;Brain Games']
# ['FAMILY', 'Puzzle;Brain Games']
# ['FAMILY', 'Board;Brain Games']
# ['FAMILY', 'Board;Action & Adventure']
# ['FAMILY', 'Casual;Brain Games']
# ['FAMILY', 'Board;Brain Games']
# ['FAMILY', 'Board;Brain Games']
# ['FAMILY', 'Casual;Music & Video']
# ['FAMILY', 'Educational;Education']
# ['FAMILY', 'Educational;Pretend Play']
# ['FAMILY', 'Education;Pretend Play']
# ['FAMILY', 'Educational;Education']
# ['FAMILY', 'Education;Music & Video']
# ['FAMILY', 'Education;Pretend Play']
# ['FAMILY', 'Role Playing;Pretend Play']
# ['FAMILY', 'Adventure;Action & Adventure']
# ['FAMILY', 'Entertainment;Music & Video']
# ['FAMILY', 'Entertainment;Music & Video']
# ['FAMILY', 'Casual;Pretend Play']
# ['FAMILY', 'Entertainment;Pretend Play']
# ['FAMILY', 'Educational;Education']
# ['FAMILY', 'Casual;Creativity']
# ['FAMILY', 'Educational;Education']
# ['FAMILY', 'Casual;Pretend Play']
# ['FAMILY', 'Racing;Action & Adventure']
# ['FAMILY', 'Educational;Education']
# ['FAMILY', 'Entertainment;Music & Video']
# ['FAMILY', 'Entertainment;Brain Games']
# ['FAMILY', 'Education;Education']
# ['FAMILY', 'Casual;Action & Adventure']
# ['FAMILY', 'Arcade;Action & Adventure']
# ['FAMILY', 'Education;Education']
# ['FAMILY', 'Casual;Pretend Play']
# ['FAMILY', 'Education;Brain Games']
# ['MEDICAL', 'Medical']
# ['MEDICAL', 'Medical']
# ['MEDICAL', 'Medical']
# ['MEDICAL', 'Medical']
# ['MEDICAL', 'Medical']
# ['MEDICAL', 'Medical']
# ['MEDICAL', 'Medical']
# ['MEDICAL', 'Medical']
# ['MEDICAL', 'Medical']
# ['MEDICAL', 'Medical']
# ['MEDICAL', 'Medical']
# ['MEDICAL', 'Medical']
# ['MEDICAL', 'Medical']
# ['MEDICAL', 'Medical']
# ['MEDICAL', 'Medical']
# ['MEDICAL', 'Medical']
# ['MEDICAL', 'Medical']
# ['MEDICAL', 'Medical']
# ['MEDICAL', 'Medical']
# ['MEDICAL', 'Medical']
# ['MEDICAL', 'Medical']
# ['MEDICAL', 'Medical']
# ...
# ['SOCIAL', 'Social']
# ['SOCIAL', 'Social']
# ['PHOTOGRAPHY', 'Photography']
# ['SOCIAL', 'Social']
# ['PRODUCTIVITY', 'Productivity']
# ['FAMILY', 'Communication;Creativity']
# ['BUSINESS', 'Business']
# ['SOCIAL', 'Social']
# ['SOCIAL', 'Social']
# ['SOCIAL', 'Social']
# ['VIDEO_PLAYERS', 'Video Players & Editors']
# ['SOCIAL', 'Social']
# ['TOOLS', 'Tools']
# ['VIDEO_PLAYERS', 'Video Players & Editors']
# ['TOOLS', 'Tools']
# ['PHOTOGRAPHY', 'Photography']
# ['SOCIAL', 'Social']
# ['TOOLS', 'Tools']
# ['SOCIAL', 'Social']
# ['SOCIAL', 'Social']
# ['SOCIAL', 'Social']
# ['PRODUCTIVITY', 'Productivity']
# ['SOCIAL', 'Social']
# ['BUSINESS', 'Business']
# ['VIDEO_PLAYERS', 'Video Players & Editors']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['FAMILY', 'Casual']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['FAMILY', 'Education']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SOCIAL', 'Social']
# ['SPORTS', 'Sports']
# ['BUSINESS', 'Business']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['NEWS_AND_MAGAZINES', 'News & Magazines']
# ['PRODUCTIVITY', 'Productivity']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['PERSONALIZATION', 'Personalization']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['COMMUNICATION', 'Communication']
# ['MAPS_AND_NAVIGATION', 'Maps & Navigation']
# ['NEWS_AND_MAGAZINES', 'News & Magazines']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['NEWS_AND_MAGAZINES', 'News & Magazines']
# ['SPORTS', 'Sports']
# ['SHOPPING', 'Shopping']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['TOOLS', 'Tools']
# ['FINANCE', 'Finance']
# ['FAMILY', 'Entertainment']
# ['FAMILY', 'Entertainment']
# ['SPORTS', 'Sports']
# ['FAMILY', 'Entertainment']
# ['FINANCE', 'Finance']
# ['BEAUTY', 'Beauty']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['FAMILY', 'Entertainment']
# ['FAMILY', 'Simulation']
# ['FINANCE', 'Finance']
# ['FAMILY', 'Entertainment']
# ['SPORTS', 'Sports']
# ['FAMILY', 'Entertainment']
# ['FAMILY', 'Simulation']
# ['FINANCE', 'Finance']
# ['TOOLS', 'Tools']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FAMILY', 'Entertainment']
# ['FINANCE', 'Finance']
# ['FAMILY', 'Entertainment']
# ['FINANCE', 'Finance']
# ['FAMILY', 'Entertainment']
# ['FAMILY', 'Entertainment']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['PHOTOGRAPHY', 'Photography']
# ['FINANCE', 'Finance']
# ['NEWS_AND_MAGAZINES', 'News & Magazines']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['SPORTS', 'Sports']
# ['VIDEO_PLAYERS', 'Video Players & Editors']
# ['FAMILY', 'Simulation']
# ['FINANCE', 'Finance']
# ['TOOLS', 'Tools']
# ['FAMILY', 'Education']
# ['FINANCE', 'Finance']
# ['FAMILY', 'Education']
# ['BUSINESS', 'Business']
# ['LIFESTYLE', 'Lifestyle']
# ['GAME', 'Action']
# ['FAMILY', 'Education']
# ['FAMILY', 'Entertainment']
# ['FAMILY', 'Education']
# ['FINANCE', 'Finance']
# ['FAMILY', 'Education']
# ['TRAVEL_AND_LOCAL', 'Travel & Local']
# ['TOOLS', 'Tools']
# ['FAMILY', 'Education']
# ['NEWS_AND_MAGAZINES', 'News & Magazines']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['PERSONALIZATION', 'Personalization']
# ['PERSONALIZATION', 'Personalization']
# ['PERSONALIZATION', 'Personalization']
# ['FINANCE', 'Finance']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['FAMILY', 'Entertainment']
# ['TOOLS', 'Tools']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['FOOD_AND_DRINK', 'Food & Drink']
# ['HOUSE_AND_HOME', 'House & Home']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['BUSINESS', 'Business']
# ['FAMILY', 'Entertainment']
# ['SOCIAL', 'Social']
# ['PERSONALIZATION', 'Personalization']
# ['TRAVEL_AND_LOCAL', 'Travel & Local']
# ['SPORTS', 'Sports']
# ['FAMILY', 'Education']
# ['LIFESTYLE', 'Lifestyle']
# ['PERSONALIZATION', 'Personalization']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['FAMILY', 'Education']
# ['FINANCE', 'Finance']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['TOOLS', 'Tools']
# ['FAMILY', 'Puzzle']
# ['FAMILY', 'Entertainment']
# ['FAMILY', 'Entertainment']
# ['GAME', 'Board']
# ['TOOLS', 'Tools']
# ['FAMILY', 'Entertainment']
# ['GAME', 'Action']
# ['GAME', 'Arcade']
# ['FAMILY', 'Strategy']
# ['BUSINESS', 'Business']
# ['GAME', 'Racing']
# ['GAME', 'Action']
# ['GAME', 'Racing']
# ['FAMILY', 'Education']
# ['GAME', 'Racing']
# ['GAME', 'Racing']
# ['FAMILY', 'Education']
# ['FAMILY', 'Entertainment']
# ['GAME', 'Action']
# ['GAME', 'Adventure']
# ['FAMILY', 'Simulation']
# ['SPORTS', 'Sports']
# ['FAMILY', 'Simulation']
# ['GAME', 'Action']
# ['SPORTS', 'Sports']
# ['PHOTOGRAPHY', 'Photography']
# ['FAMILY', 'Entertainment;Pretend Play']
# ['FAMILY', 'Simulation']
# ['FAMILY', 'Entertainment']
# ['GAME', 'Racing']
# ['FAMILY', 'Educational;Education']
# ['GAME', 'Action']
# ['FAMILY', 'Puzzle']
# ['PHOTOGRAPHY', 'Photography']
# ['PERSONALIZATION', 'Personalization']
# ['MEDICAL', 'Medical']
# ['MEDICAL', 'Medical']
# ['PERSONALIZATION', 'Personalization']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['PERSONALIZATION', 'Personalization']
# ['FAMILY', 'Puzzle']
# ['PERSONALIZATION', 'Personalization']
# ['FAMILY', 'Puzzle']
# ['FAMILY', 'Puzzle']
# ['GAME', 'Action']
# ['FAMILY', 'Education']
# ['MEDICAL', 'Medical']
# ['FAMILY', 'Education']
# ['BUSINESS', 'Business']
# ['PERSONALIZATION', 'Personalization']
# ['FAMILY', 'Puzzle']
# ['PERSONALIZATION', 'Personalization']
# ['FAMILY', 'Education']
# ['FINANCE', 'Finance']
# ['FAMILY', 'Education']
# ['GAME', 'Racing']
# ['PERSONALIZATION', 'Personalization']
# ['FAMILY', 'Puzzle']
# ['FAMILY', 'Puzzle']
# ['FAMILY', 'Simulation']
# ['FINANCE', 'Finance']
# ['TOOLS', 'Tools']
# ['SPORTS', 'Sports']
# ['FAMILY', 'Education']
# ['TOOLS', 'Tools']
# ['FAMILY', 'Casual']
# ['GAME', 'Adventure']
# ['GAME', 'Adventure']
# ['COMMUNICATION', 'Communication']
# ['FAMILY', 'Education']
# ['FAMILY', 'Casual']
# ['FAMILY', 'Puzzle']
# ['GAME', 'Adventure']
# ['FAMILY', 'Simulation']
# ['FAMILY', 'Art & Design;Creativity']
# ['COMMUNICATION', 'Communication']
# ['GAME', 'Adventure']
# ['FAMILY', 'Simulation']
# ['TOOLS', 'Tools']
# ['TOOLS', 'Tools']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['PRODUCTIVITY', 'Productivity']
# ['TOOLS', 'Tools']
# ['COMMUNICATION', 'Communication']
# ['PRODUCTIVITY', 'Productivity']
# ['TOOLS', 'Tools']
# ['COMMUNICATION', 'Communication']
# ['LIFESTYLE', 'Lifestyle']
# ['TOOLS', 'Tools']
# ['TOOLS', 'Tools']
# ['FAMILY', 'Education']
# ['FAMILY', 'Strategy']
# ['COMMUNICATION', 'Communication']
# ['PRODUCTIVITY', 'Productivity']
# ['FINANCE', 'Finance']
# ['LIFESTYLE', 'Lifestyle']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['PERSONALIZATION', 'Personalization']
# ['COMMUNICATION', 'Communication']
# ['TOOLS', 'Tools']
# ['LIFESTYLE', 'Lifestyle']
# ['PERSONALIZATION', 'Personalization']
# ['FAMILY', 'Entertainment']
# ['COMMUNICATION', 'Communication']
# ['FAMILY', 'Simulation']
# ['FAMILY', 'Simulation']
# ['PERSONALIZATION', 'Personalization']
# ['PERSONALIZATION', 'Personalization']
# ['GAME', 'Arcade']
# ['TOOLS', 'Tools']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['FAMILY', 'Simulation']
# ['TOOLS', 'Tools']
# ['FAMILY', 'Simulation']
# ['PERSONALIZATION', 'Personalization']
# ['TRAVEL_AND_LOCAL', 'Travel & Local']
# ['FAMILY', 'Simulation']
# ['FAMILY', 'Casual;Pretend Play']
# ['PERSONALIZATION', 'Personalization']
# ['PERSONALIZATION', 'Personalization']
# ['PERSONALIZATION', 'Personalization']
# ['PERSONALIZATION', 'Personalization']
# ['FAMILY', 'Simulation']
# ['PERSONALIZATION', 'Personalization']
# ['PERSONALIZATION', 'Personalization']
# ['PERSONALIZATION', 'Personalization']
# ['FAMILY', 'Racing;Action & Adventure']
# ['FAMILY', 'Simulation']
# ['FAMILY', 'Simulation']
# ['GAME', 'Racing']
# ['FAMILY', 'Casual;Pretend Play']
# ['GAME', 'Action']
# ['GAME', 'Racing']
# ['PHOTOGRAPHY', 'Photography']
# ['TOOLS', 'Tools']
# ['GAME', 'Racing']
# ['FAMILY', 'Entertainment']
# ['FAMILY', 'Simulation']
# ['FAMILY', 'Simulation']
# ['GAME', 'Adventure']
# ['PRODUCTIVITY', 'Productivity']
# ['GAME', 'Action']
# ['VIDEO_PLAYERS', 'Video Players & Editors']
# ['FAMILY', 'Simulation']
# ['GAME', 'Action']
# ['GAME', 'Racing']
# ['MEDICAL', 'Medical']
# ['GAME', 'Action']
# ['SPORTS', 'Sports']
# ['FAMILY', 'Strategy;Creativity']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['BUSINESS', 'Business']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['GAME', 'Racing']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['PRODUCTIVITY', 'Productivity']
# ['GAME', 'Racing']
# ['SPORTS', 'Sports']
# ['FAMILY', 'Entertainment']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['TOOLS', 'Tools']
# ['SPORTS', 'Sports']
# ['SPORTS', 'Sports']
# ['TRAVEL_AND_LOCAL', 'Travel & Local']
# ['FAMILY', 'Education']
# ['FAMILY', 'Entertainment']
# ['FAMILY', 'Education']
# ['FAMILY', 'Entertainment']
# ['FAMILY', 'Entertainment']
# ['PRODUCTIVITY', 'Productivity']
# ['NEWS_AND_MAGAZINES', 'News & Magazines']
# ['FAMILY', 'Entertainment']
# ['LIFESTYLE', 'Lifestyle']
# ['TOOLS', 'Tools']
# ['WEATHER', 'Weather']
# ['SPORTS', 'Sports']
# ['BUSINESS', 'Business']
# ['PRODUCTIVITY', 'Productivity']
# ['FAMILY', 'Entertainment']
# ['TRAVEL_AND_LOCAL', 'Travel & Local']
# ['TRAVEL_AND_LOCAL', 'Travel & Local']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['TOOLS', 'Tools']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['LIFESTYLE', 'Lifestyle']
# ['FAMILY', 'Education']
# ['FAMILY', 'Education']
# ['FAMILY', 'Education']
# ['NEWS_AND_MAGAZINES', 'News & Magazines']
# ['PRODUCTIVITY', 'Productivity']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['TRAVEL_AND_LOCAL', 'Travel & Local']
# ['LIFESTYLE', 'Lifestyle']
# ['TRAVEL_AND_LOCAL', 'Travel & Local']
# ['SPORTS', 'Sports']
# ['EVENTS', 'Events']
# ['PRODUCTIVITY', 'Productivity']
# ['NEWS_AND_MAGAZINES', 'News & Magazines']
# ['TRAVEL_AND_LOCAL', 'Travel & Local']
# ['LIFESTYLE', 'Lifestyle']
# ['PHOTOGRAPHY', 'Photography']
# ['LIFESTYLE', 'Lifestyle']
# ['WEATHER', 'Weather']
# ['FAMILY', 'Education']
# ['NEWS_AND_MAGAZINES', 'News & Magazines']
# ['LIFESTYLE', 'Lifestyle']
# ['NEWS_AND_MAGAZINES', 'News & Magazines']
# ['LIFESTYLE', 'Lifestyle']
# ['FAMILY', 'Entertainment']
# ['FAMILY', 'Casual']
# ['NEWS_AND_MAGAZINES', 'News & Magazines']
# ['TRAVEL_AND_LOCAL', 'Travel & Local']
# ['PRODUCTIVITY', 'Productivity']
# ['LIFESTYLE', 'Lifestyle']
# ['BUSINESS', 'Business']
# ['WEATHER', 'Weather']
# ['LIFESTYLE', 'Lifestyle']
# ['WEATHER', 'Weather']
# ['FINANCE', 'Finance']
# ['FAMILY', 'Education']
# ['HEALTH_AND_FITNESS', 'Health & Fitness']
# ['TRAVEL_AND_LOCAL', 'Travel & Local']
# ['FAMILY', 'Education']
# ['TRAVEL_AND_LOCAL', 'Travel & Local']
# ['TRAVEL_AND_LOCAL', 'Travel & Local']
# ['NEWS_AND_MAGAZINES', 'News & Magazines']
# ['GAME', 'Action']
# ['LIFESTYLE', 'Lifestyle']
# ['MAPS_AND_NAVIGATION', 'Maps & Navigation']
# ['NEWS_AND_MAGAZINES', 'News & Magazines']
# ['FAMILY', 'Education']
# ['NEWS_AND_MAGAZINES', 'News & Magazines']
# ['SHOPPING', 'Shopping']
# ['FINANCE', 'Finance']
# ['LIFESTYLE', 'Lifestyle']
# ['NEWS_AND_MAGAZINES', 'News & Magazines']
# ['VIDEO_PLAYERS', 'Video Players & Editors']
# ['PHOTOGRAPHY', 'Photography']
# ['FAMILY', 'Casual']
# ['SOCIAL', 'Social']
# ['FAMILY', 'Puzzle']
# ['PERSONALIZATION', 'Personalization']
# ['FAMILY', 'Entertainment']
# ['PERSONALIZATION', 'Personalization']
# ['PERSONALIZATION', 'Personalization']
# ['PERSONALIZATION', 'Personalization']
# ['BUSINESS', 'Business']
# ['PERSONALIZATION', 'Personalization']
# ['LIFESTYLE', 'Lifestyle']
# ['FINANCE', 'Finance']
# ['PHOTOGRAPHY', 'Photography']
# ['PERSONALIZATION', 'Personalization']
# ['COMMUNICATION', 'Communication']
# ['GAME', 'Action']
# ['COMMUNICATION', 'Communication']
# ['GAME', 'Action']
# ['TOOLS', 'Tools']
# ['PERSONALIZATION', 'Personalization']
# ['PERSONALIZATION', 'Personalization']
# ['NEWS_AND_MAGAZINES', 'News & Magazines']
# ['PRODUCTIVITY', 'Productivity']
# ['SPORTS', 'Sports']
# ['GAME', 'Action']
# ['FAMILY', 'Education']
# ['GAME', 'Action']
# ['FAMILY', 'Strategy']
# ['TOOLS', 'Tools']
# ['SOCIAL', 'Social']
# ['FAMILY', 'Entertainment']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['COMMUNICATION', 'Communication']
# ['FINANCE', 'Finance']
# ['COMMUNICATION', 'Communication']
# ['FAMILY', 'Entertainment']
# ['BUSINESS', 'Business']
# ['GAME', 'Arcade']
# ['COMMUNICATION', 'Communication']
# ['BUSINESS', 'Business']
# ['BUSINESS', 'Business']
# ['PHOTOGRAPHY', 'Photography']
# ['BUSINESS', 'Business']
# ['COMMUNICATION', 'Communication']
# ['PERSONALIZATION', 'Personalization']
# ['GAME', 'Racing']
# ['SHOPPING', 'Shopping']
# ['WEATHER', 'Weather']
# ['SOCIAL', 'Social']
# ['PHOTOGRAPHY', 'Photography']
# ['GAME', 'Action']
# ['FINANCE', 'Finance']
# ['COMMUNICATION', 'Communication']
# ['GAME', 'Arcade']
# ['PERSONALIZATION', 'Personalization']
# ['SPORTS', 'Sports']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['MAPS_AND_NAVIGATION', 'Maps & Navigation']
# ['PHOTOGRAPHY', 'Photography']
# ['TOOLS', 'Tools']
# ['TOOLS', 'Tools']
# ['LIBRARIES_AND_DEMO', 'Libraries & Demo']
# ['MEDICAL', 'Medical']
# ['FAMILY', 'Entertainment']
# ['TOOLS', 'Tools']
# ['PERSONALIZATION', 'Personalization']
# ['COMMUNICATION', 'Communication']
# ['BUSINESS', 'Business']
# ['MAPS_AND_NAVIGATION', 'Maps & Navigation']
# ['GAME', 'Racing']
# ['COMMUNICATION', 'Communication']
# ['PHOTOGRAPHY', 'Photography']
# ['TOOLS', 'Tools']
# ['LIFESTYLE', 'Lifestyle']
# ['FAMILY', 'Entertainment']
# ['FINANCE', 'Finance']
# ['FINANCE', 'Finance']
# ['TOOLS', 'Tools']
# ['PERSONALIZATION', 'Personalization']
# ['COMMUNICATION', 'Communication']
# ['GAME', 'Arcade']
# ['TOOLS', 'Tools']
# ['FAMILY', 'Education']
# ['FINANCE', 'Finance']
# ['SHOPPING', 'Shopping']
# ['BUSINESS', 'Business']
# ['MAPS_AND_NAVIGATION', 'Maps & Navigation']
# ['TOOLS', 'Tools']
# ['TOOLS', 'Tools']
# ['TOOLS', 'Tools']
# ['TOOLS', 'Tools']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['NEWS_AND_MAGAZINES', 'News & Magazines']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['SOCIAL', 'Social']
# ['TOOLS', 'Tools']
# ['EVENTS', 'Events']
# ['LIFESTYLE', 'Lifestyle']
# ['GAME', 'Action']
# ['PRODUCTIVITY', 'Productivity']
# ['BUSINESS', 'Business']
# ['LIFESTYLE', 'Lifestyle']
# ['NEWS_AND_MAGAZINES', 'News & Magazines']
# ['SPORTS', 'Sports']
# ['GAME', 'Racing']
# ['GAME', 'Arcade']
# ['FAMILY', 'Role Playing']
# ['FAMILY', 'Role Playing']
# ['FAMILY', 'Strategy']
# ['GAME', 'Action']
# ['GAME', 'Action']
# ['GAME', 'Action']
# ['TOOLS', 'Tools']
# ['GAME', 'Action']
# ['PERSONALIZATION', 'Personalization']
# ['GAME', 'Action']
# ['COMMUNICATION', 'Communication']
# ['GAME', 'Word']
# ['GAME', 'Trivia']
# ['GAME', 'Card']
# ['FAMILY', 'Casual']
# ['TOOLS', 'Tools']
# ['TOOLS', 'Tools']
# ['LIFESTYLE', 'Lifestyle']
# ['SOCIAL', 'Social']
# ['TOOLS', 'Tools']
# ['FAMILY', 'Education']
# ['FAMILY', 'Entertainment']
# ['GAME', 'Action']
# ['GAME', 'Card']
# ['LIFESTYLE', 'Lifestyle']
# ['MEDICAL', 'Medical']
# ['TOOLS', 'Tools']
# ['LIFESTYLE', 'Lifestyle']
# ['FAMILY', 'Strategy']
# ['BUSINESS', 'Business']
# ['AUTO_AND_VEHICLES', 'Auto & Vehicles']
# ['FAMILY', 'Education']
# ['BUSINESS', 'Business']
# ['FAMILY', 'Entertainment']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['BUSINESS', 'Business']
# ['TOOLS', 'Tools']
# ['FINANCE', 'Finance']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['FAMILY', 'Education']
# ['FAMILY', 'Entertainment']
# ['PRODUCTIVITY', 'Productivity']
# ['VIDEO_PLAYERS', 'Video Players & Editors']
# ['MEDICAL', 'Medical']
# ['SOCIAL', 'Social']
# ['SOCIAL', 'Social']
# ['FAMILY', 'Education']
# ['COMICS', 'Comics']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['NEWS_AND_MAGAZINES', 'News & Magazines']
# ['MAPS_AND_NAVIGATION', 'Maps & Navigation']
# ['WEATHER', 'Weather']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['FAMILY', 'Education']
# ['BUSINESS', 'Business']
# ['FAMILY', 'Education']
# ['FAMILY', 'Education']
# ['MEDICAL', 'Medical']
# ['BOOKS_AND_REFERENCE', 'Books & Reference']
# ['LIFESTYLE', 'Lifestyle']

# %% [markdown]
# We will perform our analysis with both Google data fields "Genre" and "Category", but may find that the "Category" field is simplest and sufficient to draw conclusions from.

# %% [markdown]
# ## III. Analysis
#
# We will look at two metrics. First we look at the frequency of each genre. Then we assess a different metric that may be a better measure of app genre popularity.

# %% [markdown]
# ### III.a Examine Frequency of Apps per Genre
#
# We start by building a dictionary, where the keys are the genre labels and the values are the percent of apps in that genre. Then we transform this into an ordered list of tuples to easily identify the genre with the highest percent of apps.

# %%
# Build function that, given dataset and column index, returns a frequency dictionary.

def build_freq_table(data, index_genre):
    freq_dict = {}
    
    for row in data[1:]:
        genre = row[index_genre]
        if genre in freq_dict.keys():
            freq_dict[genre] += 1
        else:
            freq_dict[genre] = 1
    
    # Convert to percentages
    total_num_apps = len(data) - 1  # We will divide by the total number of rows
    for genre in freq_dict:
        freq_dict[genre] /= total_num_apps  # Calculate proportion
        freq_dict[genre] *= 100   # Turn the proportion into a percentage
    
    return freq_dict

# %%
# Test that this works. Use the Google data, field "Categories" (index 1)

build_freq_table(google_data, 1)
# Out:
# {'ART_AND_DESIGN': 0.6442133815551537,
#  'AUTO_AND_VEHICLES': 0.9267631103074141,
#  'BEAUTY': 0.599005424954792,
#  'BOOKS_AND_REFERENCE': 2.1360759493670884,
#  'BUSINESS': 4.599909584086799,
#  'COMICS': 0.6103074141048824,
#  'COMMUNICATION': 3.2323688969258586,
#  'DATING': 1.8648282097649187,
#  'EDUCATION': 1.164104882459313,
#  'ENTERTAINMENT': 0.9606690777576853,
#  'EVENTS': 0.7120253164556962,
#  'FINANCE': 3.7070524412296564,
#  'FOOD_AND_DRINK': 1.2432188065099457,
#  'HEALTH_AND_FITNESS': 3.0854430379746836,
#  'HOUSE_AND_HOME': 0.8024412296564195,
#  'LIBRARIES_AND_DEMO': 0.9380650994575045,
#  'LIFESTYLE': 3.887884267631103,
#  'GAME': 9.697106690777577,
#  'FAMILY': 18.942133815551536,
#  'MEDICAL': 3.5375226039783,
#  'SOCIAL': 2.667269439421338,
#  'SHOPPING': 2.2490958408679926,
#  'PHOTOGRAPHY': 2.949819168173599,
#  'SPORTS': 3.390596745027125,
#  'TRAVEL_AND_LOCAL': 2.3395117540687163,
#  'TOOLS': 8.453887884267631,
#  'PERSONALIZATION': 3.322784810126582,
#  'PRODUCTIVITY': 3.899186256781193,
#  'PARENTING': 0.6555153707052441,
#  'WEATHER': 0.7911392405063291,
#  'VIDEO_PLAYERS': 1.7970162748643763,
#  'NEWS_AND_MAGAZINES': 2.802893309222423,
#  'MAPS_AND_NAVIGATION': 1.3901446654611211}

# %%
# Now we turn the dictionary pairs into tuples, which will allow us to sort these by value.

def sort_freq_table(data, index_genre):
    freq_dict = build_freq_table(data, index_genre)
    tuples_list = []
    
    for key in freq_dict:
        new_tuple = (freq_dict[key], key)
        tuples_list.append(new_tuple)
    
    sorted_list = sorted(tuples_list, reverse=True)  # We want the order to be from greatest to least
    
#    return sorted_list

# %% [markdown]
# **Review results.**
#
# Let's look at the ordered lists for each data set. Then we will note some observations.

# %%
# Google data. Field "Categories" (index 1).

sort_freq_table(google_data, 1)

# %%
# Google data. Field "Genres" (index 9).

sort_freq_table(google_data, 9)

# %%
# Google data. Field "prime_genre" (index 11).

sort_freq_table(apple_data, 11)

# %% [markdown]
# From these results we see that the most common Apple apps tend to be for enjoyment ("Games", "Entertainment", and "Photo and Video" are top three), while the most common Google apps include both apps for enjoyment and those for pragmatic purposes ("Tools" is one of the top genres/categories).
#
# However, the most common genre does not necessarily tell us what is the most popular genre amongst users. So we need to ask, what field can we use as an indicator of the number of users using the apps?

# %% [markdown]
# ### III.b Analyze Genre Popularity with Average Number of Reviews
#
# There are a couple data points we may look at as a proxy for number of users using the apps. The Google data has a field called "Installs" - the number of times the app was installed on a device. However, this field is categorical, with values like "10,000+" - we will need to convert these to numeric values before we can perform any calculations with the numbers. We will do this by simply removing the "+" and "," symbols in the string and using the number remaining - it will be an approximation, but that's good enough for our purposes.
#
# In the Apple data there is no field that counts number of installs, so we will use the number of reviews as a proxy for th number of users using the app. This can be found in the field "rating_count_tot".
#
# Simply counting frequency of the reviews per genre will not give us a good measure of popularity - the number of genres that have more apps are likely to also have more reviews. So instead we will find the average number of reviews, by calculating the number of reviews per number of apps in each genre.

# %%
# Calculate number of installs or reviews per number of apps for each genre
# Build this as a dictionary, then convert to an ordered list of tuples.

def avg_num_reviews(data, index_genre, index_count):
    genres_dict = build_freq_table(data, index_genre)
    avg_reviews_dict = {}
    
    for genre in genres_dict:
        count_apps = genres_dict[genre]
        count_reviews = 0
        
        for row in data:
            if row[index_genre] == genre:
                  # Select the relevant column value - be it number of installs or number of reviews
                add_count = row[index_count]
                  # Use str.replace to remove '+' and ',' from the values in the case of the Google data
                add_count = add_count.replace('+','').replace(',','')
                add_count = float(add_count)
                count_reviews += add_count
        
        avg_reviews = count_reviews / count_apps
        avg_reviews_dict[genre] = avg_reviews
    
    # Turn the dictionary value-key pairs into tuples then sort by value.
    tuples_list = []
    
    for key in avg_reviews_dict:
        new_tuple = (avg_reviews_dict[key], key)
        tuples_list.append(new_tuple)
    
    sorted_list = sorted(tuples_list, reverse=True)  # We want the order to be from greatest to least
    
    return sorted_list

# %%
# Google data; group by 'Categories' (index 1); calculating average 'Installs' (index 5)

avg_num_reviews(google_data, 1, 5)
# Out:
# [(3414494614.614266, 'COMMUNICATION'),
#  (2187922154.626415, 'VIDEO_PLAYERS'),
#  (2057483140.2074578, 'SOCIAL'),
#  (1578492968.3954022, 'PHOTOGRAPHY'),
#  (1485343077.3991885, 'PRODUCTIVITY'),
#  (1375334403.8881118, 'GAME'),
#  (1237311195.7936232, 'TRAVEL_AND_LOCAL'),
#  (1029969656.4705883, 'ENTERTAINMENT'),
#  (958260694.3576471, 'TOOLS'),
#  (844911310.8258065, 'NEWS_AND_MAGAZINES'),
#  (779880397.2740741, 'BOOKS_AND_REFERENCE'),
#  (622622904.5266331, 'SHOPPING'),
#  (460227181.53142864, 'PERSONALIZATION'),
#  (455278289.28000003, 'WEATHER'),
#  (370626969.26358974, 'HEALTH_AND_FITNESS'),
#  (358279819.6292683, 'MAPS_AND_NAVIGATION'),
#  (326990388.21670645, 'FAMILY'),
#  (323005289.43946666, 'SPORTS'),
#  (175750928.5614035, 'ART_AND_DESIGN'),
#  (170314951.71345454, 'FOOD_AND_DRINK'),
#  (162227650.4854369, 'EDUCATION'),
#  (151503432.24373466, 'BUSINESS'),
#  (127956079.64511627, 'LIFESTYLE'),
#  (122783030.24195123, 'FINANCE'),
#  (120385714.77859156, 'HOUSE_AND_HOME'),
#  (75564470.90521212, 'DATING'),
#  (73669676.8888889, 'COMICS'),
#  (57274680.454634145, 'AUTO_AND_VEHICLES'),
#  (56494810.46746988, 'LIBRARIES_AND_DEMO'),
#  (48009568.35862069, 'PARENTING'),
#  (45403678.943396226, 'BEAUTY'),
#  (22433415.82222222, 'EVENTS'),
#  (10666318.840638978, 'MEDICAL')]

# %%
# Google data; group by 'Genres' (index 9); calculating average 'Installs' (index 5)

avg_num_reviews(google_data, 9, 5)
# Out:
# [(3414494614.614266, 'Communication'),
#  (3126293333.3333335, 'Adventure;Action & Adventure'),
#  (2207340271.24586, 'Video Players & Editors'),
#  (2057483140.2074578, 'Social'),
#  (2037532606.4490795, 'Arcade'),
#  (1731484727.3948717, 'Casual'),
#  (1625082666.6666667, 'Puzzle;Action & Adventure'),
#  (1578492968.3954022, 'Photography'),
#  (1505634666.6666667, 'Educational;Action & Adventure'),
#  (1485343077.3991885, 'Productivity'),
#  (1407773929.9272728, 'Racing'),
#  (1243274609.3654368, 'Travel & Local'),
#  (1142866666.6666667, 'Casual;Action & Adventure'),
#  (1103089505.2963505, 'Action'),
#  (990967375.9308643, 'Strategy'),
#  (958359035.3139492, 'Tools'),
#  (884800000.0, 'Tools;Education'),
#  (884800000.0, 'Role Playing;Brain Games'),
#  (884800000.0, 'Lifestyle;Pretend Play'),
#  (884800000.0, 'Casual;Music & Video'),
#  (884800000.0, 'Card;Action & Adventure'),
#  (884800000.0, 'Adventure;Education'),
#  (844911310.8258065, 'News & Magazines'),
#  (835745213.3333333, 'Music'),
#  (829500000.0, 'Educational;Pretend Play'),
#  (821153386.6666667, 'Puzzle;Brain Games'),
#  (804677705.3913044, 'Word'),
#  (780098666.6666667, 'Racing;Action & Adventure'),
#  (779880397.2740741, 'Books & Reference'),
#  (734637221.7967999, 'Puzzle'),
#  (663600000.0, 'Video Players & Editors;Music & Video'),
#  (622622904.5266331, 'Shopping'),
#  (619360000.0, 'Role Playing;Action & Adventure'),
#  (615568000.0, 'Casual;Pretend Play'),
#  (567451733.3333334, 'Entertainment;Music & Video'),
#  (521048888.88888884, 'Action;Action & Adventure'),
#  (495735104.74022305, 'Entertainment'),
#  (471893333.3333334, 'Education;Brain Games'),
#  (471893333.3333334, 'Casual;Creativity'),
#  (466732000.0, 'Role Playing;Pretend Play'),
#  (460227181.53142864, 'Personalization'),
#  (455278289.28000003, 'Weather'),
#  (446824000.0, 'Sports;Action & Adventure'),
#  (446824000.0, 'Music;Music & Video'),
#  (442400000.0, 'Video Players & Editors;Creativity'),
#  (429760000.0, 'Simulation;Action & Adventure'),
#  (421122064.16, 'Education;Education'),
#  (421094822.7294118, 'Board'),
#  (408043355.6596078, 'Sports'),
#  (392261333.3333334, 'Educational;Brain Games'),
#  (370626969.26358974, 'Health & Fitness'),
#  (367967504.70508474, 'Adventure'),
#  (358279819.6292683, 'Maps & Navigation'),
#  (353920000.0, 'Entertainment;Creativity'),
#  (350880306.9108434, 'Role Playing'),
#  (337592122.0, 'Card'),
#  (311486905.0810811, 'Casino'),
#  (307531059.9351351, 'Trivia'),
#  (307510832.14143646, 'Simulation'),
#  (293248000.0, 'Entertainment;Brain Games'),
#  (282331644.40727276, 'Arcade;Action & Adventure'),
#  (265440000.0, 'Entertainment;Pretend Play'),
#  (265440000.0, 'Board;Action & Adventure'),
#  (254380000.0, 'Education;Creativity'),
#  (206453333.33333334, 'Entertainment;Action & Adventure'),
#  (206453333.33333334, 'Educational;Creativity'),
#  (187829851.4716981, 'Art & Design'),
#  (179909333.33333334, 'Education;Music & Video'),
#  (170314951.71345454, 'Food & Drink'),
#  (159264000.0, 'Education;Pretend Play'),
#  (153702425.28, 'Educational;Education'),
#  (151503432.24373466, 'Business'),
#  (126165106.66666667, 'Casual;Brain Games'),
#  (125749537.60326532, 'Lifestyle'),
#  (122783030.24195123, 'Finance'),
#  (120385714.77859156, 'House & Home'),
#  (98950133.33333334, 'Parenting;Music & Video'),
#  (88480000.0, 'Strategy;Creativity'),
#  (88480000.0, 'Strategy;Action & Adventure'),
#  (88480000.0, 'Racing;Pretend Play'),
#  (88480000.0, 'Parenting;Brain Games'),
#  (88480000.0, 'Health & Fitness;Action & Adventure'),
#  (88480000.0, 'Entertainment;Education'),
#  (88480000.0, 'Education;Action & Adventure'),
#  (88480000.0, 'Casual;Education'),
#  (88480000.0, 'Arcade;Pretend Play'),
#  (75564470.90521212, 'Dating'),
#  (74976199.09433962, 'Comics'),
#  (66360000.0, 'Puzzle;Creativity'),
#  (57274680.454634145, 'Auto & Vehicles'),
#  (56494810.46746988, 'Libraries & Demo'),
#  (48680408.0, 'Education'),
#  (48664000.0, 'Simulation;Pretend Play'),
#  (45403678.943396226, 'Beauty'),
#  (44240000.0, 'Strategy;Education'),
#  (44240000.0, 'Music & Audio;Music & Video'),
#  (44240000.0, 'Communication;Creativity'),
#  (44240000.0, 'Art & Design;Pretend Play'),
#  (41406649.2, 'Parenting'),
#  (40068800.0, 'Parenting;Education'),
#  (36381635.3939394, 'Educational'),
#  (36024000.0, 'Board;Brain Games'),
#  (25216800.0, 'Art & Design;Creativity'),
#  (22433415.82222222, 'Events'),
#  (10666318.840638978, 'Medical'),
#  (8848000.0, 'Travel & Local;Action & Adventure'),
#  (8848000.0, 'Puzzle;Education'),
#  (8848000.0, 'Lifestyle;Education'),
#  (8848000.0, 'Health & Fitness;Education'),
#  (8848000.0, 'Art & Design;Action & Adventure'),
#  (4424000.0, 'Comics;Creativity'),
#  (88480.0, 'Books & Reference;Education'),
#  (44240.0, 'Simulation;Education'),
#  (8848.0, 'Trivia;Education')]

# %%
# Apple data; group by 'prime_genre' (index 11); calculating average 'rating_count_tot' (index 5)

avg_num_reviews(apple_data, 11, 5)
# Out:
# [(2734337.866, 'Reference'),
#  (2289781.4901492535, 'Music'),
#  (2151790.0579020977, 'Social Networking'),
#  (1914336.724516129, 'Weather'),
#  (1104710.6304191616, 'Photo & Video'),
#  (1052906.907, 'Navigation'),
#  (819557.3639285713, 'Travel'),
#  (818060.4311627909, 'Food & Drink'),
#  (816028.6336708859, 'Sports'),
#  (808866.8821052632, 'Health & Fitness'),
#  (772444.5829032258, 'Productivity'),
#  (767884.2481330377, 'Games'),
#  (759990.3133884298, 'Shopping'),
#  (644291.0365517242, 'News'),
#  (567969.4911926605, 'Utilities'),
#  (548192.4976190475, 'Finance'),
#  (438762.84209580836, 'Entertainment'),
#  (363980.62702127657, 'Lifestyle'),
#  (344522.43333333335, 'Book'),
#  (258150.612, 'Business'),
#  (254037.15333333335, 'Education'),
#  (72143.18222222221, 'Catalogs'),
#  (18638.264999999996, 'Medical')]

# %% [markdown]
# ## IV. Draw Conclusions
#
# We already decided that popularity of app genres - approximated by the number of installs or reviews - would be a better metric to look at than number of apps in each genre. So we draw our conclusions from the latter analysis.
#
# Social networking, photo, and video apps seem to be a common popular genres on both platforms. "Social Networking" and "Photo and Video" are in the top five most popular Apple app genres, and "Social", "Photo", and "Video Players" are in the top five categories on Google apps.
#
# From this, we may decide on a recommendation for what type of app our clients should build that would be successful on both platforms: Build a social networking app, or perhaps a photo or video app that has a social component.
